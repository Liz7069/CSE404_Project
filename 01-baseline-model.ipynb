# %% [markdown]
# # Baseline Model

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("../data/real-estate-cleaned.csv")
df.head()
# Out:
#    List Year Date Recorded        Town  Assessed Value  Sale Amount  \
# 0       2010       10/2/10     Norwalk        339640.0     265000.0
# 1       2010       10/3/10     Milford        674350.0     788000.0
# 2       2010       10/4/10  Bridgeport        132250.0     148000.0
# 3       2010       10/4/10     Bristol         99610.0      32000.0
# 4       2010       10/4/10  Bridgeport        132260.0     110000.0
#
#   Property Type Residential Type                Location
# 0   Residential    Single Family  POINT (-73.408 41.118)
# 1   Residential    Single Family  POINT (-73.057 41.222)
# 2   Residential    Single Family  POINT (-73.195 41.186)
# 3   Residential    Single Family   POINT (-72.94 41.671)
# 4   Residential    Single Family  POINT (-73.195 41.186)

# %%
print(df.shape)
print(df.columns)
# Out:
# (614534, 8)
# Index(['List Year', 'Date Recorded', 'Town', 'Assessed Value', 'Sale Amount',
#        'Property Type', 'Residential Type', 'Location'],
#       dtype='str')
